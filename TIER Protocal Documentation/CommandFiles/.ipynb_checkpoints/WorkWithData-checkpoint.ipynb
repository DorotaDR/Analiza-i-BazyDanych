# %%
import pandas as pd

# %% [markdown]
# # Wczytywanie danych

# %%
file_path = "..\OriginalData\dem_score.xlsx"

# %%
final_file_path = "..\AnalysisData\dem_score_final.csv"

# %%
df = pd.read_excel(file_path)

# %%
df
# Out:
#             country  1952  1957  1962  1967  1972  1977  1982  1987  1992
# 0           Albania    -9    -9    -9    -9    -9    -9    -9    -9     5
# 1         Argentina    -9    -1    -1    -9    -9    -9    -8     8     7
# 2           Armenia    -9    -7    -7    -7    -7    -7    -7    -7     7
# 3         Australia    10    10    10    10    10    10    10    10    10
# 4           Austria    10    10    10    10    10    10    10    10    10
# 5        Azerbaijan    -9    -7    -7    -7    -7    -7    -7    -7     1
# 6           Belarus    -9    -7    -7    -7    -7    -7    -7    -7     7
# 7           Belgium    10    10    10    10    10    10    10    10    10
# 8            Bhutan   -10   -10   -10   -10   -10   -10   -10   -10   -10
# 9           Bolivia    -4    -3    -3    -4    -7    -7     8     9     9
# 10           Brazil     5     5     5    -9    -9    -4    -3     7     8
# 11         Bulgaria    -7    -7    -7    -7    -7    -7    -7    -7     8
# ...

# %%
data_melt = pd.melt(df,id_vars='country')

# %%
data_melt
# Out:
#              country variable  value
# 0            Albania     1952     -9
# 1          Argentina     1952     -9
# 2            Armenia     1952     -9
# 3          Australia     1952     10
# 4            Austria     1952     10
# 5         Azerbaijan     1952     -9
# 6            Belarus     1952     -9
# 7            Belgium     1952     10
# 8             Bhutan     1952    -10
# 9            Bolivia     1952     -4
# 10            Brazil     1952      5
# 11          Bulgaria     1952     -7
# 12            Canada     1952     10
# 13             Chile     1952      2
# 14             China     1952     -8
# 15          Colombia     1952     -5
# 16        Costa Rica     1952     10
# 17           Croatia     1952     -7
# 18              Cuba     1952      0
# 19        Czech Rep.     1952     -7
# 20           Denmark     1952     10
# 21    Dominican Rep.     1952     -9
# 22           Ecuador     1952      2
# 23             Egypt     1952     -7
# ...

# %%
data_melt.rename(columns={"variable": "year", "value": "domocratic_lvl"}, inplace=True)

(data_melt)
# Out:
#              country  year  domocratic_lvl
# 0            Albania  1952              -9
# 1          Argentina  1952              -9
# 2            Armenia  1952              -9
# 3          Australia  1952              10
# 4            Austria  1952              10
# 5         Azerbaijan  1952              -9
# 6            Belarus  1952              -9
# 7            Belgium  1952              10
# 8             Bhutan  1952             -10
# 9            Bolivia  1952              -4
# 10            Brazil  1952               5
# 11          Bulgaria  1952              -7
# 12            Canada  1952              10
# 13             Chile  1952               2
# 14             China  1952              -8
# 15          Colombia  1952              -5
# 16        Costa Rica  1952              10
# 17           Croatia  1952              -7
# 18              Cuba  1952               0
# 19        Czech Rep.  1952              -7
# 20           Denmark  1952              10
# ...

# %%
data_melt.to_csv(final_file_path, index = False)

# %%
# Check saved data

# %%
saved_df = pd.read_csv(final_file_path)

# %%
saved_df
# Out:
#              country  year  domocratic_lvl
# 0            Albania  1952              -9
# 1          Argentina  1952              -9
# 2            Armenia  1952              -9
# 3          Australia  1952              10
# 4            Austria  1952              10
# 5         Azerbaijan  1952              -9
# 6            Belarus  1952              -9
# 7            Belgium  1952              10
# 8             Bhutan  1952             -10
# 9            Bolivia  1952              -4
# 10            Brazil  1952               5
# 11          Bulgaria  1952              -7
# 12            Canada  1952              10
# 13             Chile  1952               2
# 14             China  1952              -8
# 15          Colombia  1952              -5
# 16        Costa Rica  1952              10
# 17           Croatia  1952              -7
# 18              Cuba  1952               0
# 19        Czech Rep.  1952              -7
# 20           Denmark  1952              10
# ...
